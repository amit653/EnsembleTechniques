# %% [markdown]
# <a href="https://colab.research.google.com/github/amit653/EnsembleTechniques/blob/master/cnn_facedetectionipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import tensorflow as tf
#configuration for memory management
gpus = tf.config.experimental.list_physical_devices('GPU')

if gpus:
    #### When GPU is found in current running environment ####
     try:
     # Currently, memory growth needs to be the same across GPUs
         for gpu in gpus:
             tf.config.experimental.set_memory_growth(gpu, True)
             logical_gpus = tf.config.experimental.list_logical_devices('GPU')
             print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
        
     except RuntimeError as e:

     # Memory growth must be set before GPUs have been initialized
         print(e)
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
#Importing required librarires
import csv
import math
import cv2

import numpy as np
import tensorflow as tf
from PIL import Image
from tensorflow.keras import Model
from tensorflow.keras.applications.mobilenet import MobileNet, preprocess_input
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import Concatenate, Conv2D, UpSampling2D, Reshape
from tensorflow.keras.utils import Sequence
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import binary_crossentropy
from tensorflow.keras.backend import log, epsilon

from matplotlib import pyplot as plt
#loading the data
data = np.load('/content/drive/My Drive/DLCP/Project-2/images.npy',allow_pickle=True)
#verifying the data attributes
print (data.shape)  # (409,2)
print (data.dtype)
# Out:
# (409, 2)
# object

# %%
#Check one sample from the loaded "images.npy" file (4 marks)
#visulaizing the loaded data
print(data.shape)
print(type(data))

print (data[10, 1]) #  raw image  position stored in JSON format
#visulaizing the loaded data
plt.imshow(data[10,0])
plt.show()
# Out:
# (409, 2)
# <class 'numpy.ndarray'>
# [{'label': ['Face'], 'notes': '', 'points': [{'x': 0.48, 'y': 0.10385756676557864}, {'x': 0.7716666666666666, 'y': 0.6795252225519288}], 'imageWidth': 600, 'imageHeight': 337}]

# %%
#Set image dimensions (2 marks)
#   Initialize image height, image width with value: 224


# setting up all the required hyperparameters
ALPHA = 1 # Width hyper parameter for MobileNet (0.25, 0.5, 0.75, 1.0). Higher width means more accurate but slower

IMAGE_HEIGHT = 224
IMAGE_WIDTH = 224

HEIGHT_CELLS = 28
WIDTH_CELLS = 28

CELL_WIDTH = IMAGE_WIDTH / WIDTH_CELLS
CELL_HEIGHT = IMAGE_HEIGHT / HEIGHT_CELLS

EPOCHS = 50
BATCH_SIZE = 4
PATIENCE = 10

THREADS = 1

# %%
#Create features and labels
#
#    Here feature is the image
#   The label is the mask
#   Images will be stored in "X_train" array
#  Masks will be stored in "masks" array

#preprocessing the input images and the masks

masks = np.zeros((int(data.shape[0]), IMAGE_HEIGHT, IMAGE_WIDTH))
X_train = np.zeros((int(data.shape[0]), IMAGE_HEIGHT, IMAGE_WIDTH, 3))
for index in range(data.shape[0]):
    img = data[index][0]
    img = cv2.resize(img, dsize=(IMAGE_HEIGHT, IMAGE_WIDTH), interpolation=cv2.INTER_CUBIC)
    try:
      img = img[:, :, :3]
    except:
      continue
    X_train[index] = preprocess_input(np.array(img, dtype=np.float32))
    for i in data[index][1]:
        x1 = int(i["points"][0]['x'] * IMAGE_WIDTH)
        x2 = int(i["points"][1]['x'] * IMAGE_WIDTH)
        y1 = int(i["points"][0]['y'] * IMAGE_HEIGHT)
        y2 = int(i["points"][1]['y'] * IMAGE_HEIGHT)
        masks[index][y1:y2, x1:x2] = 1

# %%
#Print the shape of X_train and mask array (1 mark)
print (X_train.shape) #we have 409 images of size 224 x 224 and with 3 channels (RGB)
print(masks.shape )#we have 409 masks of size 224 x 224

#Print a sample image and image array
from matplotlib import pyplot
plt.imshow(X_train[10])
plt.show()
plt.imshow(masks[10])
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (409, 224, 224, 3)
# (409, 224, 224)

# %%
print("image array :", X_train[0]) # print image array
# Out:
# image array : [[[-0.57647061 -0.6156863  -0.63921571]
#   [-0.41960782 -0.4588235  -0.48235291]
#   [-0.54509807 -0.57647061 -0.60784316]
#   ...
#   [-0.79607844 -0.71764708 -0.70980394]
#   [-0.84313726 -0.7647059  -0.7647059 ]
#   [-0.80392158 -0.72549021 -0.71764708]]
#
#  [[-0.60784316 -0.64705884 -0.67058825]
#   [-0.4588235  -0.49803919 -0.52156866]
#   [-0.49803919 -0.53725493 -0.56078434]
#   ...
#   [-0.8509804  -0.81960785 -0.83529413]
#   [-0.8509804  -0.81176472 -0.83529413]
#   [-0.75686276 -0.72549021 -0.74117649]]
#
#  [[-0.60784316 -0.64705884 -0.67058825]
#   [-0.51372552 -0.5529412  -0.57647061]
#   [-0.52941179 -0.56862748 -0.59215689]
#   ...
#   [-0.77254903 -0.78823531 -0.82745099]
#   [-0.7647059  -0.78039217 -0.81960785]
#   [-0.73333335 -0.74901962 -0.78823531]]
#
#  ...
#
#  [[-0.50588238 -0.57647061 -0.63137257]
#   [-0.45098037 -0.52156866 -0.59215689]
#   [-0.46666664 -0.52941179 -0.6156863 ]
#   ...
#   [-0.27058822 -0.45098037 -0.51372552]
#   [-0.43529409 -0.60000002 -0.63921571]
#   [-0.53725493 -0.7019608  -0.75686276]]
#
#  [[-0.56078434 -0.63137257 -0.68627453]
#   [-0.4588235  -0.52941179 -0.60000002]
#   [-0.49019605 -0.5529412  -0.63921571]
#   ...
#   [-0.25490195 -0.43529409 -0.49803919]
#   [-0.48235291 -0.63921571 -0.67843139]
#   [-0.56862748 -0.72549021 -0.78039217]]
#
#  [[-0.57647061 -0.64705884 -0.7019608 ]
#   [-0.46666664 -0.53725493 -0.60784316]
#   [-0.49803919 -0.56078434 -0.64705884]
#   ...
#   [-0.27843136 -0.4588235  -0.51372552]
#   [-0.48235291 -0.64705884 -0.68627453]
#   [-0.46666664 -0.62352943 -0.67843139]]]

# %%
# resizing the masks to 28 * 28 for faster implementation of the model
masks_resized = np.zeros((int(data.shape[0]), 28, 28))
for mask_len in range(masks.shape[0]):
 masks_resized[mask_len] = cv2.resize(masks[mask_len], (28,28))
print (masks.shape, masks_resized.shape)
# Out:
# (409, 224, 224) (409, 28, 28)

# %%
plt.imshow(X_train[10])
plt.show()
plt.imshow(masks_resized[10])
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
'''
Create the model (10 marks)

    Add MobileNet as model with below parameter values
        input_shape: IMAGE_HEIGHT, IMAGE_WIDTH, 3
        include_top: False
        alpha: 1.0
        weights: "imagenet"
    Add UNET architecture layers
        This is the trickiest part of the project, you need to research and implement it correctly
'''
def create_model(trainable=True):
    #using transposed learning , using mobilenet architecture with the weights of imagenet
    model = MobileNet(input_shape=(IMAGE_HEIGHT, IMAGE_WIDTH, 3), include_top=False, alpha=ALPHA, weights="imagenet")

    for layer in model.layers:
        layer.trainable = trainable

        #Unet architecture implementation
        #from mobilenet the pointwise layers are chosen , upsampled and concantenated with the layer before downsampling
    block1 = model.get_layer("conv_pw_5_relu").output #28 *28 layer before downsampling to 14 *14
    block2 = model.get_layer("conv_pw_11_relu").output #14 *14 layer before downsampling to 7 *7
    block3 = model.get_layer("conv_pw_13_relu").output #7 *7 layer 

    x = Concatenate()([UpSampling2D()(block3), block2])
    x = Concatenate()([UpSampling2D()(x), block1])

    x = Conv2D(1, kernel_size=1, activation="sigmoid")(x) #final activation function
    x = Reshape((HEIGHT_CELLS, WIDTH_CELLS))(x) #reshaping output to 28 * 28

    return Model(inputs=model.input, outputs=x)
#Define dice coefficient function (5 marks)
#   Create a function to calculate dice coefficient


def dice_coefficient(y_true, y_pred):
    numerator = 2 * tf.reduce_sum(y_true * y_pred)
    denominator = tf.reduce_sum(y_true + y_pred)

    return numerator / (denominator + epsilon())
def loss(y_true, y_pred):
    return binary_crossentropy(y_true, y_pred) - log(dice_coefficient(y_true, y_pred) + tf.keras.backend.epsilon())

# %%
#Call the create_model function
model = create_model(False)
model.summary()
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.0/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.6/mobilenet_1_0_224_tf_no_top.h5
# 17227776/17225924 [==============================] - 0s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 225, 225, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 112, 112, 32) 864         conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 112, 112, 32) 128         conv1[0][0]
# __________________________________________________________________________________________________
# conv1_relu (ReLU)               (None, 112, 112, 32) 0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# conv_dw_1 (DepthwiseConv2D)     (None, 112, 112, 32) 288         conv1_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_1_bn (BatchNormalizatio (None, 112, 112, 32) 128         conv_dw_1[0][0]
# __________________________________________________________________________________________________
# conv_dw_1_relu (ReLU)           (None, 112, 112, 32) 0           conv_dw_1_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_1 (Conv2D)              (None, 112, 112, 64) 2048        conv_dw_1_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_1_bn (BatchNormalizatio (None, 112, 112, 64) 256         conv_pw_1[0][0]
# __________________________________________________________________________________________________
# conv_pw_1_relu (ReLU)           (None, 112, 112, 64) 0           conv_pw_1_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_2 (ZeroPadding2D)      (None, 113, 113, 64) 0           conv_pw_1_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_2 (DepthwiseConv2D)     (None, 56, 56, 64)   576         conv_pad_2[0][0]
# __________________________________________________________________________________________________
# conv_dw_2_bn (BatchNormalizatio (None, 56, 56, 64)   256         conv_dw_2[0][0]
# __________________________________________________________________________________________________
# conv_dw_2_relu (ReLU)           (None, 56, 56, 64)   0           conv_dw_2_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_2 (Conv2D)              (None, 56, 56, 128)  8192        conv_dw_2_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_2_bn (BatchNormalizatio (None, 56, 56, 128)  512         conv_pw_2[0][0]
# __________________________________________________________________________________________________
# conv_pw_2_relu (ReLU)           (None, 56, 56, 128)  0           conv_pw_2_bn[0][0]
# __________________________________________________________________________________________________
# conv_dw_3 (DepthwiseConv2D)     (None, 56, 56, 128)  1152        conv_pw_2_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_3_bn (BatchNormalizatio (None, 56, 56, 128)  512         conv_dw_3[0][0]
# __________________________________________________________________________________________________
# conv_dw_3_relu (ReLU)           (None, 56, 56, 128)  0           conv_dw_3_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_3 (Conv2D)              (None, 56, 56, 128)  16384       conv_dw_3_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_3_bn (BatchNormalizatio (None, 56, 56, 128)  512         conv_pw_3[0][0]
# __________________________________________________________________________________________________
# conv_pw_3_relu (ReLU)           (None, 56, 56, 128)  0           conv_pw_3_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_4 (ZeroPadding2D)      (None, 57, 57, 128)  0           conv_pw_3_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_4 (DepthwiseConv2D)     (None, 28, 28, 128)  1152        conv_pad_4[0][0]
# __________________________________________________________________________________________________
# conv_dw_4_bn (BatchNormalizatio (None, 28, 28, 128)  512         conv_dw_4[0][0]
# __________________________________________________________________________________________________
# conv_dw_4_relu (ReLU)           (None, 28, 28, 128)  0           conv_dw_4_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_4 (Conv2D)              (None, 28, 28, 256)  32768       conv_dw_4_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_4_bn (BatchNormalizatio (None, 28, 28, 256)  1024        conv_pw_4[0][0]
# __________________________________________________________________________________________________
# conv_pw_4_relu (ReLU)           (None, 28, 28, 256)  0           conv_pw_4_bn[0][0]
# __________________________________________________________________________________________________
# conv_dw_5 (DepthwiseConv2D)     (None, 28, 28, 256)  2304        conv_pw_4_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_5_bn (BatchNormalizatio (None, 28, 28, 256)  1024        conv_dw_5[0][0]
# __________________________________________________________________________________________________
# conv_dw_5_relu (ReLU)           (None, 28, 28, 256)  0           conv_dw_5_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_5 (Conv2D)              (None, 28, 28, 256)  65536       conv_dw_5_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_5_bn (BatchNormalizatio (None, 28, 28, 256)  1024        conv_pw_5[0][0]
# __________________________________________________________________________________________________
# conv_pw_5_relu (ReLU)           (None, 28, 28, 256)  0           conv_pw_5_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_6 (ZeroPadding2D)      (None, 29, 29, 256)  0           conv_pw_5_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_6 (DepthwiseConv2D)     (None, 14, 14, 256)  2304        conv_pad_6[0][0]
# __________________________________________________________________________________________________
# conv_dw_6_bn (BatchNormalizatio (None, 14, 14, 256)  1024        conv_dw_6[0][0]
# __________________________________________________________________________________________________
# conv_dw_6_relu (ReLU)           (None, 14, 14, 256)  0           conv_dw_6_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_6 (Conv2D)              (None, 14, 14, 512)  131072      conv_dw_6_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_6_bn (BatchNormalizatio (None, 14, 14, 512)  2048        conv_pw_6[0][0]
# __________________________________________________________________________________________________
# conv_pw_6_relu (ReLU)           (None, 14, 14, 512)  0           conv_pw_6_bn[0][0]
# __________________________________________________________________________________________________
# conv_dw_7 (DepthwiseConv2D)     (None, 14, 14, 512)  4608        conv_pw_6_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_7_bn (BatchNormalizatio (None, 14, 14, 512)  2048        conv_dw_7[0][0]
# __________________________________________________________________________________________________
# conv_dw_7_relu (ReLU)           (None, 14, 14, 512)  0           conv_dw_7_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_7 (Conv2D)              (None, 14, 14, 512)  262144      conv_dw_7_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_7_bn (BatchNormalizatio (None, 14, 14, 512)  2048        conv_pw_7[0][0]
# __________________________________________________________________________________________________
# conv_pw_7_relu (ReLU)           (None, 14, 14, 512)  0           conv_pw_7_bn[0][0]
# __________________________________________________________________________________________________
# conv_dw_8 (DepthwiseConv2D)     (None, 14, 14, 512)  4608        conv_pw_7_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_8_bn (BatchNormalizatio (None, 14, 14, 512)  2048        conv_dw_8[0][0]
# __________________________________________________________________________________________________
# conv_dw_8_relu (ReLU)           (None, 14, 14, 512)  0           conv_dw_8_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_8 (Conv2D)              (None, 14, 14, 512)  262144      conv_dw_8_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_8_bn (BatchNormalizatio (None, 14, 14, 512)  2048        conv_pw_8[0][0]
# __________________________________________________________________________________________________
# conv_pw_8_relu (ReLU)           (None, 14, 14, 512)  0           conv_pw_8_bn[0][0]
# __________________________________________________________________________________________________
# conv_dw_9 (DepthwiseConv2D)     (None, 14, 14, 512)  4608        conv_pw_8_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_9_bn (BatchNormalizatio (None, 14, 14, 512)  2048        conv_dw_9[0][0]
# __________________________________________________________________________________________________
# conv_dw_9_relu (ReLU)           (None, 14, 14, 512)  0           conv_dw_9_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_9 (Conv2D)              (None, 14, 14, 512)  262144      conv_dw_9_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_9_bn (BatchNormalizatio (None, 14, 14, 512)  2048        conv_pw_9[0][0]
# __________________________________________________________________________________________________
# conv_pw_9_relu (ReLU)           (None, 14, 14, 512)  0           conv_pw_9_bn[0][0]
# __________________________________________________________________________________________________
# conv_dw_10 (DepthwiseConv2D)    (None, 14, 14, 512)  4608        conv_pw_9_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_10_bn (BatchNormalizati (None, 14, 14, 512)  2048        conv_dw_10[0][0]
# __________________________________________________________________________________________________
# conv_dw_10_relu (ReLU)          (None, 14, 14, 512)  0           conv_dw_10_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_10 (Conv2D)             (None, 14, 14, 512)  262144      conv_dw_10_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_10_bn (BatchNormalizati (None, 14, 14, 512)  2048        conv_pw_10[0][0]
# __________________________________________________________________________________________________
# conv_pw_10_relu (ReLU)          (None, 14, 14, 512)  0           conv_pw_10_bn[0][0]
# __________________________________________________________________________________________________
# conv_dw_11 (DepthwiseConv2D)    (None, 14, 14, 512)  4608        conv_pw_10_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_11_bn (BatchNormalizati (None, 14, 14, 512)  2048        conv_dw_11[0][0]
# __________________________________________________________________________________________________
# conv_dw_11_relu (ReLU)          (None, 14, 14, 512)  0           conv_dw_11_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_11 (Conv2D)             (None, 14, 14, 512)  262144      conv_dw_11_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_11_bn (BatchNormalizati (None, 14, 14, 512)  2048        conv_pw_11[0][0]
# __________________________________________________________________________________________________
# conv_pw_11_relu (ReLU)          (None, 14, 14, 512)  0           conv_pw_11_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_12 (ZeroPadding2D)     (None, 15, 15, 512)  0           conv_pw_11_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_12 (DepthwiseConv2D)    (None, 7, 7, 512)    4608        conv_pad_12[0][0]
# __________________________________________________________________________________________________
# conv_dw_12_bn (BatchNormalizati (None, 7, 7, 512)    2048        conv_dw_12[0][0]
# __________________________________________________________________________________________________
# conv_dw_12_relu (ReLU)          (None, 7, 7, 512)    0           conv_dw_12_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_12 (Conv2D)             (None, 7, 7, 1024)   524288      conv_dw_12_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_12_bn (BatchNormalizati (None, 7, 7, 1024)   4096        conv_pw_12[0][0]
# __________________________________________________________________________________________________
# conv_pw_12_relu (ReLU)          (None, 7, 7, 1024)   0           conv_pw_12_bn[0][0]
# __________________________________________________________________________________________________
# conv_dw_13 (DepthwiseConv2D)    (None, 7, 7, 1024)   9216        conv_pw_12_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_13_bn (BatchNormalizati (None, 7, 7, 1024)   4096        conv_dw_13[0][0]
# __________________________________________________________________________________________________
# conv_dw_13_relu (ReLU)          (None, 7, 7, 1024)   0           conv_dw_13_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_13 (Conv2D)             (None, 7, 7, 1024)   1048576     conv_dw_13_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_13_bn (BatchNormalizati (None, 7, 7, 1024)   4096        conv_pw_13[0][0]
# __________________________________________________________________________________________________
# conv_pw_13_relu (ReLU)          (None, 7, 7, 1024)   0           conv_pw_13_bn[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 14, 14, 1024) 0           conv_pw_13_relu[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 14, 14, 1536) 0           up_sampling2d[0][0]
#                                                                  conv_pw_11_relu[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 28, 28, 1536) 0           concatenate[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 28, 28, 1792) 0           up_sampling2d_1[0][0]
#                                                                  conv_pw_5_relu[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 28, 28, 1)    1793        concatenate_1[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 28, 28)       0           conv2d[0][0]
# ==================================================================================================
# Total params: 3,230,657
# Trainable params: 1,793
# Non-trainable params: 3,228,864
# __________________________________________________________________________________________________

# %%
#Define checkpoint and earlystopping
checkpoint = ModelCheckpoint("model-{loss:.2f}.h5", monitor="loss", verbose=1, save_best_only=True,
                             save_weights_only=True, mode="min", period=1)
stop = EarlyStopping(monitor="loss", patience=5, mode="min")
reduce_lr = ReduceLROnPlateau(monitor="loss", factor=0.2, patience=5, min_lr=1e-6, verbose=1, mode="min")
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of samples seen.

# %%
#Train-test data split
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X_train, masks_resized, test_size=0.30, random_state=1)

# %%
'''
Compile the model (5 marks)

    Complie the model using below parameters
        loss: use the loss function defined above
        optimizers: use Adam optimizer
        metrics: use dice_coefficient function defined above

'''
optimizer = Adam(lr=1e-4, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
model.compile(loss=loss, optimizer=optimizer, metrics=[dice_coefficient])

# %%
#fit the model
'''
Fit the model (5 marks)

    Fit the model using below parameters
        epochs: you can decide
        batch_size: 1
        callbacks: checkpoint, reduce_lr, stop
'''
model.fit(x=X_train,
 y=y_train,
 epochs=EPOCHS,
 callbacks=[checkpoint, reduce_lr, stop],
 batch_size = BATCH_SIZE,
 validation_data=(X_val, y_val), verbose=1
 )
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.0/python3.6/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 286 samples, validate on 123 samples
# Epoch 1/50
# 284/286 [============================>.] - ETA: 0s - loss: 2.6572 - dice_coefficient: 0.1862
# Epoch 00001: loss improved from inf to 2.65965, saving model to model-2.66.h5
# 286/286 [==============================] - 42s 145ms/sample - loss: 2.6597 - dice_coefficient: 0.1849 - val_loss: 2.2570 - val_dice_coefficient: 0.2101
# Epoch 2/50
# 284/286 [============================>.] - ETA: 0s - loss: 1.9705 - dice_coefficient: 0.2469
# Epoch 00002: loss improved from 2.65965 to 1.97185, saving model to model-1.97.h5
# 286/286 [==============================] - 39s 136ms/sample - loss: 1.9718 - dice_coefficient: 0.2469 - val_loss: 1.8373 - val_dice_coefficient: 0.2661
# Epoch 3/50
# 284/286 [============================>.] - ETA: 0s - loss: 1.6264 - dice_coefficient: 0.3083
# Epoch 00003: loss improved from 1.97185 to 1.62262, saving model to model-1.62.h5
# 286/286 [==============================] - 39s 136ms/sample - loss: 1.6226 - dice_coefficient: 0.3110 - val_loss: 1.5630 - val_dice_coefficient: 0.3324
# Epoch 4/50
# 284/286 [============================>.] - ETA: 0s - loss: 1.3656 - dice_coefficient: 0.3740
# Epoch 00004: loss improved from 1.62262 to 1.36785, saving model to model-1.37.h5
# 286/286 [==============================] - 39s 137ms/sample - loss: 1.3679 - dice_coefficient: 0.3730 - val_loss: 1.4005 - val_dice_coefficient: 0.3649
# Epoch 5/50
# 284/286 [============================>.] - ETA: 0s - loss: 1.3000 - dice_coefficient: 0.3953
# Epoch 00005: loss improved from 1.36785 to 1.30039, saving model to model-1.30.h5
# 286/286 [==============================] - 39s 136ms/sample - loss: 1.3004 - dice_coefficient: 0.3949 - val_loss: 1.2842 - val_dice_coefficient: 0.3984
# Epoch 6/50
# 284/286 [============================>.] - ETA: 0s - loss: 1.1752 - dice_coefficient: 0.4324
# Epoch 00006: loss improved from 1.30039 to 1.17558, saving model to model-1.18.h5
# 286/286 [==============================] - 39s 136ms/sample - loss: 1.1756 - dice_coefficient: 0.4315 - val_loss: 1.2316 - val_dice_coefficient: 0.4222
# Epoch 7/50
# 284/286 [============================>.] - ETA: 0s - loss: 1.1367 - dice_coefficient: 0.4475
# Epoch 00007: loss improved from 1.17558 to 1.13492, saving model to model-1.13.h5
# 286/286 [==============================] - 39s 136ms/sample - loss: 1.1349 - dice_coefficient: 0.4495 - val_loss: 1.1423 - val_dice_coefficient: 0.4419
# Epoch 8/50
# 284/286 [============================>.] - ETA: 0s - loss: 1.0756 - dice_coefficient: 0.4682
# Epoch 00008: loss improved from 1.13492 to 1.07591, saving model to model-1.08.h5
# 286/286 [==============================] - 39s 136ms/sample - loss: 1.0759 - dice_coefficient: 0.4685 - val_loss: 1.1217 - val_dice_coefficient: 0.4525
# Epoch 9/50
# 284/286 [============================>.] - ETA: 0s - loss: 1.0354 - dice_coefficient: 0.4845
# Epoch 00009: loss improved from 1.07591 to 1.03387, saving model to model-1.03.h5
# 286/286 [==============================] - 39s 137ms/sample - loss: 1.0339 - dice_coefficient: 0.4856 - val_loss: 1.0528 - val_dice_coefficient: 0.4750
# Epoch 10/50
# 284/286 [============================>.] - ETA: 0s - loss: 0.9790 - dice_coefficient: 0.5036
# Epoch 00010: loss improved from 1.03387 to 0.97978, saving model to model-0.98.h5
# 286/286 [==============================] - 39s 137ms/sample - loss: 0.9798 - dice_coefficient: 0.5035 - val_loss: 1.0357 - val_dice_coefficient: 0.4823
# Epoch 11/50
# 284/286 [============================>.] - ETA: 0s - loss: 0.9566 - dice_coefficient: 0.5128
# Epoch 00011: loss improved from 0.97978 to 0.96133, saving model to model-0.96.h5
# 286/286 [==============================] - 39s 136ms/sample - loss: 0.9613 - dice_coefficient: 0.5099 - val_loss: 1.0540 - val_dice_coefficient: 0.4811
# Epoch 12/50
# 284/286 [============================>.] - ETA: 0s - loss: 0.9774 - dice_coefficient: 0.5065
# Epoch 00012: loss did not improve from 0.96133
# 286/286 [==============================] - 38s 135ms/sample - loss: 0.9828 - dice_coefficient: 0.5056 - val_loss: 1.0026 - val_dice_coefficient: 0.4962
# Epoch 13/50
# 284/286 [============================>.] - ETA: 0s - loss: 0.9467 - dice_coefficient: 0.5187
# Epoch 00013: loss improved from 0.96133 to 0.94442, saving model to model-0.94.h5
# 286/286 [==============================] - 39s 137ms/sample - loss: 0.9444 - dice_coefficient: 0.5201 - val_loss: 0.9720 - val_dice_coefficient: 0.5078
# Epoch 14/50
# 284/286 [============================>.] - ETA: 0s - loss: 0.9375 - dice_coefficient: 0.5221
# Epoch 00014: loss improved from 0.94442 to 0.93579, saving model to model-0.94.h5
# 286/286 [==============================] - 39s 136ms/sample - loss: 0.9358 - dice_coefficient: 0.5236 - val_loss: 0.9350 - val_dice_coefficient: 0.5208
# Epoch 15/50
# 284/286 [============================>.] - ETA: 0s - loss: 0.9118 - dice_coefficient: 0.5362
# Epoch 00015: loss improved from 0.93579 to 0.91281, saving model to model-0.91.h5
# 286/286 [==============================] - 38s 133ms/sample - loss: 0.9128 - dice_coefficient: 0.5351 - val_loss: 0.9698 - val_dice_coefficient: 0.5137
# Epoch 16/50
# 284/286 [============================>.] - ETA: 0s - loss: 0.8996 - dice_coefficient: 0.5403
# Epoch 00016: loss improved from 0.91281 to 0.89872, saving model to model-0.90.h5
# 286/286 [==============================] - 38s 132ms/sample - loss: 0.8987 - dice_coefficient: 0.5404 - val_loss: 0.9336 - val_dice_coefficient: 0.5266
# Epoch 17/50
# 284/286 [============================>.] - ETA: 0s - loss: 0.8875 - dice_coefficient: 0.5454
# Epoch 00017: loss improved from 0.89872 to 0.88586, saving model to model-0.89.h5
# 286/286 [==============================] - 38s 133ms/sample - loss: 0.8859 - dice_coefficient: 0.5468 - val_loss: 0.9142 - val_dice_coefficient: 0.5331
# Epoch 18/50
# 284/286 [============================>.] - ETA: 0s - loss: 0.8569 - dice_coefficient: 0.5572
# Epoch 00018: loss improved from 0.88586 to 0.85687, saving model to model-0.86.h5
# 286/286 [==============================] - 39s 135ms/sample - loss: 0.8569 - dice_coefficient: 0.5562 - val_loss: 0.8875 - val_dice_coefficient: 0.5427
# Epoch 19/50
# 284/286 [============================>.] - ETA: 0s - loss: 0.8566 - dice_coefficient: 0.5578
# Epoch 00019: loss did not improve from 0.85687
# 286/286 [==============================] - 39s 136ms/sample - loss: 0.8671 - dice_coefficient: 0.5519 - val_loss: 0.8945 - val_dice_coefficient: 0.5367
# Epoch 20/50
# 284/286 [============================>.] - ETA: 0s - loss: 0.8530 - dice_coefficient: 0.5618
# Epoch 00020: loss did not improve from 0.85687
# 286/286 [==============================] - 39s 135ms/sample - loss: 0.8616 - dice_coefficient: 0.5560 - val_loss: 0.9133 - val_dice_coefficient: 0.5380
# Epoch 21/50
# 284/286 [============================>.] - ETA: 0s - loss: 0.8503 - dice_coefficient: 0.5613
# Epoch 00021: loss improved from 0.85687 to 0.85048, saving model to model-0.85.h5
# 286/286 [==============================] - 38s 133ms/sample - loss: 0.8505 - dice_coefficient: 0.5606 - val_loss: 0.9029 - val_dice_coefficient: 0.5444
# Epoch 22/50
# 284/286 [============================>.] - ETA: 0s - loss: 0.8745 - dice_coefficient: 0.5526
# Epoch 00022: loss did not improve from 0.85048
# 286/286 [==============================] - 38s 132ms/sample - loss: 0.8749 - dice_coefficient: 0.5522 - val_loss: 0.8753 - val_dice_coefficient: 0.5511
# Epoch 23/50
# 284/286 [============================>.] - ETA: 0s - loss: 0.8294 - dice_coefficient: 0.5692
# Epoch 00023: loss improved from 0.85048 to 0.83418, saving model to model-0.83.h5
# 286/286 [==============================] - 38s 133ms/sample - loss: 0.8342 - dice_coefficient: 0.5650 - val_loss: 0.8760 - val_dice_coefficient: 0.5479
# Epoch 24/50
# 284/286 [============================>.] - ETA: 0s - loss: 0.8376 - dice_coefficient: 0.5664
# Epoch 00024: loss did not improve from 0.83418
# 286/286 [==============================] - 38s 133ms/sample - loss: 0.8381 - dice_coefficient: 0.5673 - val_loss: 0.8576 - val_dice_coefficient: 0.5603
# Epoch 25/50
# 284/286 [============================>.] - ETA: 0s - loss: 0.8194 - dice_coefficient: 0.5750
# Epoch 00025: loss improved from 0.83418 to 0.81826, saving model to model-0.82.h5
# 286/286 [==============================] - 38s 133ms/sample - loss: 0.8183 - dice_coefficient: 0.5764 - val_loss: 0.8598 - val_dice_coefficient: 0.5596
# Epoch 26/50
# 284/286 [============================>.] - ETA: 0s - loss: 0.7871 - dice_coefficient: 0.5883
# Epoch 00026: loss improved from 0.81826 to 0.78961, saving model to model-0.79.h5
# 286/286 [==============================] - 38s 133ms/sample - loss: 0.7896 - dice_coefficient: 0.5858 - val_loss: 0.8551 - val_dice_coefficient: 0.5606
# Epoch 27/50
# 284/286 [============================>.] - ETA: 0s - loss: 0.8020 - dice_coefficient: 0.5794
# Epoch 00027: loss did not improve from 0.78961
# 286/286 [==============================] - 38s 133ms/sample - loss: 0.8077 - dice_coefficient: 0.5777 - val_loss: 0.8639 - val_dice_coefficient: 0.5599
# Epoch 28/50
# 284/286 [============================>.] - ETA: 0s - loss: 0.7971 - dice_coefficient: 0.5838
# Epoch 00028: loss did not improve from 0.78961
# 286/286 [==============================] - 38s 134ms/sample - loss: 0.7970 - dice_coefficient: 0.5836 - val_loss: 0.8805 - val_dice_coefficient: 0.5581
# Epoch 29/50
# 284/286 [============================>.] - ETA: 0s - loss: 0.8034 - dice_coefficient: 0.5808
# Epoch 00029: loss did not improve from 0.78961
# 286/286 [==============================] - 38s 133ms/sample - loss: 0.8014 - dice_coefficient: 0.5827 - val_loss: 0.8389 - val_dice_coefficient: 0.5699
# Epoch 30/50
# 284/286 [============================>.] - ETA: 0s - loss: 0.7952 - dice_coefficient: 0.5886
# Epoch 00030: loss did not improve from 0.78961
# 286/286 [==============================] - 38s 133ms/sample - loss: 0.7935 - dice_coefficient: 0.5890 - val_loss: 0.8664 - val_dice_coefficient: 0.5636
# Epoch 31/50
# 284/286 [============================>.] - ETA: 0s - loss: 0.7655 - dice_coefficient: 0.5976
# Epoch 00031: loss improved from 0.78961 to 0.76453, saving model to model-0.76.h5
# 286/286 [==============================] - 38s 133ms/sample - loss: 0.7645 - dice_coefficient: 0.5987 - val_loss: 0.8397 - val_dice_coefficient: 0.5709
# Epoch 32/50
# 284/286 [============================>.] - ETA: 0s - loss: 0.7940 - dice_coefficient: 0.5865
# Epoch 00032: loss did not improve from 0.76453
# 286/286 [==============================] - 38s 132ms/sample - loss: 0.7931 - dice_coefficient: 0.5866 - val_loss: 0.8139 - val_dice_coefficient: 0.5826
# Epoch 33/50
# 284/286 [============================>.] - ETA: 0s - loss: 0.8038 - dice_coefficient: 0.5830
# Epoch 00033: loss did not improve from 0.76453
# 286/286 [==============================] - 38s 132ms/sample - loss: 0.8025 - dice_coefficient: 0.5845 - val_loss: 0.8821 - val_dice_coefficient: 0.5672
# Epoch 34/50
# 284/286 [============================>.] - ETA: 0s - loss: 0.7513 - dice_coefficient: 0.6047
# Epoch 00034: loss improved from 0.76453 to 0.75206, saving model to model-0.75.h5
# 286/286 [==============================] - 38s 133ms/sample - loss: 0.7521 - dice_coefficient: 0.6032 - val_loss: 0.8411 - val_dice_coefficient: 0.5733
# Epoch 35/50
# 284/286 [============================>.] - ETA: 0s - loss: 0.7752 - dice_coefficient: 0.5962
# Epoch 00035: loss did not improve from 0.75206
# 286/286 [==============================] - 38s 132ms/sample - loss: 0.7748 - dice_coefficient: 0.5966 - val_loss: 0.8721 - val_dice_coefficient: 0.5676
# Epoch 36/50
# 284/286 [============================>.] - ETA: 0s - loss: 0.7742 - dice_coefficient: 0.5977
# Epoch 00036: loss did not improve from 0.75206
# 286/286 [==============================] - 38s 133ms/sample - loss: 0.7742 - dice_coefficient: 0.5978 - val_loss: 0.8220 - val_dice_coefficient: 0.5801
# Epoch 37/50
# 284/286 [============================>.] - ETA: 0s - loss: 0.7809 - dice_coefficient: 0.5922
# Epoch 00037: loss did not improve from 0.75206
# 286/286 [==============================] - 38s 132ms/sample - loss: 0.7822 - dice_coefficient: 0.5915 - val_loss: 0.8491 - val_dice_coefficient: 0.5758
# Epoch 38/50
# 284/286 [============================>.] - ETA: 0s - loss: 0.7440 - dice_coefficient: 0.6089
# Epoch 00038: loss improved from 0.75206 to 0.74536, saving model to model-0.75.h5
# 286/286 [==============================] - 38s 133ms/sample - loss: 0.7454 - dice_coefficient: 0.6070 - val_loss: 0.8277 - val_dice_coefficient: 0.5835
# Epoch 39/50
# 284/286 [============================>.] - ETA: 0s - loss: 0.7460 - dice_coefficient: 0.6077
# Epoch 00039: loss did not improve from 0.74536
# 286/286 [==============================] - 38s 133ms/sample - loss: 0.7463 - dice_coefficient: 0.6067 - val_loss: 0.8490 - val_dice_coefficient: 0.5720
# Epoch 40/50
# 284/286 [============================>.] - ETA: 0s - loss: 0.7606 - dice_coefficient: 0.6035
# Epoch 00040: loss did not improve from 0.74536
# 286/286 [==============================] - 38s 132ms/sample - loss: 0.7618 - dice_coefficient: 0.6027 - val_loss: 0.8152 - val_dice_coefficient: 0.5858
# Epoch 41/50
# 284/286 [============================>.] - ETA: 0s - loss: 0.7567 - dice_coefficient: 0.6049
# Epoch 00041: loss did not improve from 0.74536
# 286/286 [==============================] - 38s 132ms/sample - loss: 0.7564 - dice_coefficient: 0.6047 - val_loss: 0.8255 - val_dice_coefficient: 0.5795
# Epoch 42/50
# 284/286 [============================>.] - ETA: 0s - loss: 0.7693 - dice_coefficient: 0.5966
# Epoch 00042: loss did not improve from 0.74536
# 286/286 [==============================] - 38s 132ms/sample - loss: 0.7680 - dice_coefficient: 0.5982 - val_loss: 0.8177 - val_dice_coefficient: 0.5872
# Epoch 43/50
# 284/286 [============================>.] - ETA: 0s - loss: 0.7556 - dice_coefficient: 0.6036
# Epoch 00043: loss did not improve from 0.74536
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 286/286 [==============================] - 38s 132ms/sample - loss: 0.7541 - dice_coefficient: 0.6051 - val_loss: 0.8329 - val_dice_coefficient: 0.5817

# %% [markdown]
# Execution ended at 43rd epoch with
#
# 132ms/sample - loss: 0.75 - dice_coefficient: 0.60 - val_loss: 0.8329 - val_dice_coefficient: 0.58

# %%
#Get the predicted mask for a sample image (5 marks)
predicted_mask = model.predict(X_train)

# %%
def impose_mask_3Dimage(X, mask):
 
 resized_mask = cv2.resize(mask, (X.shape[0], X.shape[1]), 1)#resizing the mask to the input image size
 mask_rgb = np.zeros_like(X)
 ### imposing mask on each channel ###
 for i in range(3):
     mask_rgb[:,:,i] = X[:,:,i] * resized_mask #wherever mask is one ,copy the input image value
 return mask_rgb

# %%
def plot_images(index , X , preicted_mask):
    print("Original image")
    plt.imshow(X[index])
    plt.show()
    print("Original mask")
    plt.imshow(masks[index])
    plt.show()
    print("Predicted mask")
    plt.imshow(predicted_mask[index])
    plt.show()
    print("Predicted mask imposed on original image")
    plt.imshow(impose_mask_3Dimage(X[index], predicted_mask[index]))
    plt.show()

# %%
#Impose the mask on the image (5 marks)
plot_images(10,X_train,predicted_mask)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Original image
# Original mask
# Predicted mask
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Predicted mask imposed on original image
# '\nConclusion\n\n    we have implemented the Unet layers on top of mobilenet architecture.\n    loss: 0.75 - dice_coefficient: 0.60 - val_loss: 0.8329 - val_dice_coefficient: 0.60\n    Training accuracy is good but the validation accuracy is not great\n    Further, the model should be improved with deeper unet (more contraction and less expansion)\n   models such as UNet have improved accuracy \n   '

# %%
'''
Conclusion

    we have implemented the Unet layers on top of mobilenet architecture.
    loss: 0.75 - dice_coefficient: 0.60 - val_loss: 0.8329 - val_dice_coefficient: 0.60
    Training accuracy is good but the validation accuracy is not great
    Further, the model should be improved with deeper unet (more contraction and less expansion)
   models such as UNet have improved accuracy 
   '''
# Out:
# '\nConclusion\n\n    we have implemented the Unet layers on top of mobilenet architecture.\n    loss: 0.75 - dice_coefficient: 0.60 - val_loss: 0.8329 - val_dice_coefficient: 0.60\n    Training accuracy is good but the validation accuracy is not great\n    Further, the model should be improved with deeper unet (more contraction and less expansion)\n   models such as UNet have improved accuracy \n   '
